# %%
import pandas as pd
import numpy as np
import random as rd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
from sklearn.cluster import KMeans
import os
import warnings
warnings.filterwarnings('ignore')

# %%
data = pd.read_csv('../../dataset/Mall_Customers.csv')
data.head()
# Out:
#    CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0           1    Male   19                  15                      39
# 1           2    Male   21                  15                      81
# 2           3  Female   20                  16                       6
# 3           4  Female   23                  16                      77
# 4           5  Female   31                  17                      40

# %%
data.rename(index=str, columns={'Annual Income (k$)' : 'A_Income', 'Spending Score (1-100)' : 'score'}, inplace=True)
data
# Out:
#      CustomerID  Gender  Age  A_Income  score
# 0             1    Male   19        15     39
# 1             2    Male   21        15     81
# 2             3  Female   20        16      6
# 3             4  Female   23        16     77
# 4             5  Female   31        17     40
# ..          ...     ...  ...       ...    ...
# 195         196  Female   35       120     79
# 196         197  Female   45       126     28
# 197         198    Male   32       126     74
# 198         199    Male   32       137     18
# 199         200    Male   30       137     83
#
# [200 rows x 5 columns]

# %%
new_data = data.drop(['CustomerID', 'Gender'], axis=1)
new_data
# Out:
#      Age  A_Income  score
# 0     19        15     39
# 1     21        15     81
# 2     20        16      6
# 3     23        16     77
# 4     31        17     40
# ..   ...       ...    ...
# 195   35       120     79
# 196   45       126     28
# 197   32       126     74
# 198   32       137     18
# 199   30       137     83
#
# [200 rows x 3 columns]

# %%
data.describe()
data.isnull().sum()
# Out:
# CustomerID    0
# Gender        0
# Age           0
# A_Income      0
# score         0
# dtype: int64

# %%
plt.figure(1, figsize=(6, 6))
sns.countplot(x = 'Gender', data = data, palette='Set1')
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.displot(data["Age"])
plt.xlabel("Age")
plt.show()

# %%
kn1 = KMeans(n_clusters=1).fit(new_data)

new_data['Labels'] = kn1.labels_
plt.figure(figsize=(12, 8))
sns.scatterplot(x = new_data['A_Income'], y = new_data['score'], hue=new_data['Labels'], palette=sns.color_palette('hls', 3))
plt.title('KMeans with One Cluster')
# Out:
# Text(0.5, 1.0, 'KMeans with One Cluster')

# %%
kn2 = KMeans(n_clusters=2).fit(new_data)

new_data['Labels'] = kn2.labels_
plt.figure(figsize=(12, 8))
sns.scatterplot(x = new_data['A_Income'], y = new_data['score'], hue=new_data['Labels'], palette=sns.color_palette('hls', 3))
plt.title('KMeans with Two Cluster')
# Out:
# Text(0.5, 1.0, 'KMeans with Two Cluster')

# %%
kn3 = KMeans(n_clusters=3).fit(new_data)

new_data['Labels'] = kn3.labels_
plt.figure(figsize=(12, 8))
sns.scatterplot(x = new_data['A_Income'], y = new_data['score'], hue=new_data['Labels'], palette=sns.color_palette('hls', 3))
plt.title('KMeans with Three Cluster')
# Out:
# Text(0.5, 1.0, 'KMeans with Three Cluster')

# %%
kn4 = KMeans(n_clusters=4).fit(new_data)

new_data['Labels'] = kn4.labels_
plt.figure(figsize=(12, 8))
sns.scatterplot(x = new_data['A_Income'], y = new_data['score'], hue=new_data['Labels'], palette=sns.color_palette('hls', 4))
plt.title('KMeans with Four Cluster')
# Out:
# Text(0.5, 1.0, 'KMeans with Four Cluster')

# %%
kn5 = KMeans(n_clusters=5).fit(new_data)

new_data['Labels'] = kn5.labels_
plt.figure(figsize=(12, 8))
sns.scatterplot(x = new_data['A_Income'], y = new_data['score'], hue=new_data['Labels'], palette=sns.color_palette('hls', 5))
plt.title('KMeans with Five Cluster')
# Out:
# Text(0.5, 1.0, 'KMeans with Five Cluster')

# %%
fig, axes = plt.subplots(figsize=(8, 6))
sns.barplot(x = 'Labels', y = 'A_Income', data = new_data, palette=sns.color_palette('hls', 5))
axes.set_title('Labels According to Annual Income')
plt.show()

# %%
X1 = data[['Age', 'score']].iloc[:, :].values
inertia = []
for n in range(1, 11):
    algorithm = (KMeans(n_clusters=n, init='k-means++', n_init=10, max_iter=100, tol=0.0001, random_state=111, algorithm='elkan'))
    algorithm.fit(X1)
    inertia.append(algorithm.inertia_)

# %%
plt.figure(1, figsize=(12, 6))
plt.plot(np.arange(1, 11), inertia, 'o')
plt.plot(np.arange(1, 11), inertia, '-', alpha = 0.5)
plt.xlabel('Number of Clusters'), plt.ylabel('Inertia')
plt.show()

# %%
#Showing segmentation using Annual Income and Spending Score

X2 = data[['A_Income', 'score']].iloc[:, :].values
inertia = []
for n in range(1, 11):
    algorithm = (KMeans(n_clusters=n, init='k-means++', n_init=10, max_iter=100, tol=0.0001, random_state=111, algorithm='elkan'))
    algorithm.fit(X2)
    inertia.append(algorithm.inertia_)

# %%
plt.figure(1, figsize=(12, 6))
plt.plot(np.arange(1, 11), inertia, 'o')
plt.plot(np.arange(1, 11), inertia, '-', alpha = 0.5)
plt.xlabel('Number of Clusters'), plt.ylabel('Inertia')
plt.show()

# %%
#Showing segmentation using Age, Spending Score and Annual Income

X3 = data[['Age', 'score', 'A_Income']].iloc[:, :].values
inertia = []
for n in range(1, 11):
    algorithm = (KMeans(n_clusters=n, init='k-means++', n_init=10, max_iter=100, tol=0.0001, random_state=111, algorithm='elkan'))
    algorithm.fit(X3)
    inertia.append(algorithm.inertia_)

# %%
plt.figure(1, figsize=(12, 6))
plt.plot(np.arange(1, 11), inertia, 'o')
plt.plot(np.arange(1, 11), inertia, '-', alpha = 0.5)
plt.xlabel('Number of Clusters'), plt.ylabel('Inertia')
plt.show()
